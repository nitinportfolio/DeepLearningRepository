# %%
# Importing Tensorflow
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.5.0

# %%
#Most of the times the default data type would be int32
# Default would be int if tensor has only int data types & flaot if any of the tensor is float

# %%
A = tf.constant([1.0,5.0])

# %%
A.dtype
# Out:
# tf.float32

# %%
B = tf.constant([1,5])
B.dtype
# Out:
# tf.int32

# %%
# Changing from float32 to float16 (reduced precision)
# Look for tensor precision documentation
# moredern processors are faster with float16 than float32 bit

# %%
A_16 = tf.cast(B, dtype = tf.float16)
A_16.dtype , '\n', A_16
# Out:
# (tf.float16,
#  '\n',
#  <tf.Tensor: shape=(2,), dtype=float16, numpy=array([1., 5.], dtype=float16)>)

# %%
# Changing from int32 to float32
B_fl32 = tf.cast(B, dtype = tf.float32)
B_fl32.dtype, B_fl32
# Out:
# (tf.float32,
#  <tf.Tensor: shape=(2,), dtype=float32, numpy=array([1., 5.], dtype=float32)>)
